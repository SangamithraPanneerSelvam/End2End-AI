# %%
import pandas as pd
dataset=pd.read_csv("wedding_info.csv")

# %%
"""To replace the fillers and remove whitespace"""
def imputing(lis=list):
  for i in lis:
    df=dataset.replace(i,'',regex=True)

  df=df.apply(lambda x:x.str.strip() if x.dtype == "object" else x)
  return df
  

df=imputing(['\n','\t',','])
df
# Out:
#      Unnamed: 0                                            Summary  \
# 0             0  How much does a summer wedding in Camarillo CA...
# 1             1  How much does a spring wedding in Mobile AL wi...
# 2             2  How much does a spring wedding with 50 to 100 ...
# 3             3  How much does a fall wedding in Dayton OH with...
# 4             4  How much does a spring wedding in Gloucester M...
# ..          ...                                                ...
# 975         975  How much does a summer wedding in Phoenix az w...
# 976         976  How much does a summer wedding in Decatur IL w...
# 977         977  How much does a fall wedding in Mount Pleasant...
# 978         978  How much does a spring wedding in Bethlehem PA...
# 979         979  How much does a summer wedding in Sheffield MA...
#
#              Season Wedding_destination  \
# 0    Summer Wedding        Camarillo CA
# 1    Spring Wedding           Mobile AL
# 2    Spring Wedding      None specified
# 3      Fall Wedding           Dayton OH
# 4    Spring Wedding       Gloucester MA
# ..              ...                 ...
# 975  Summer Wedding          Phoenix az
# 976  Summer Wedding          Decatur IL
# 977    Fall Wedding   Mount Pleasant SC
# 978  Spring Wedding        Bethlehem PA
# 979  Summer Wedding        Sheffield MA
#
#                                                  Guest  \
# 0    This estimate is based on having 175 guests wi...
# 1    This estimate is based on having 175 guests wi...
# 2    This estimate is based on having 75 guests wit...
# 3    This estimate is based on having 38 guests wit...
# 4    This estimate is based on having 125 guests wi...
# ..                                                 ...
# 975  This estimate is based on having 75 guests wit...
# 976  This estimate is based on having 75 guests wit...
# 977  This estimate is based on having 125 guests wi...
# 978  This estimate is based on having 125 guests wi...
# 979  This estimate is based on having 125 guests wi...
#
#                                Location            Describing_words  \
# 0                      a garden or park                       Pinks
# 1                                 Other                         NaN
# 2                      a garden or park                       Blues
# 3    a church or other place of worship   Romantic Vintage Intimate
# 4                     an event facility                     Purples
# ..                                  ...                         ...
# 975  a church or other place of worship  Elegant Garden Traditional
# 976                             Purples                         NaN
# 977                      a farm or barn                     Purples
# 978  a church or other place of worship    Simple Traditional Other
# 979            a family or friends home                       Blues
#
#                                          Priority_1  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3    Attire & Accessories (Wedding Dress Suit etc.)
# 4                                               NaN
# ..                                              ...
# 975  Attire & Accessories (Wedding Dress Suit etc.)
# 976                                             NaN
# 977                                             NaN
# 978         Event Food Service Catering Bar Service
# 979                                             NaN
#
#                                   Priority_2            Priority_3  \
# 0                                        NaN                   NaN
# 1                                        NaN                   NaN
# 2                                        NaN                   NaN
# 3    Event Food Service Catering Bar Service   Photography & Video
# 4                                        NaN                   NaN
# ..                                       ...                   ...
# 975  Event Food Service Catering Bar Service  Event Location/Venue
# 976                                      NaN                   NaN
# 977                                      NaN                   NaN
# 978                     Event Location/Venue         Event Rentals
# 979                                      NaN                   NaN
#
#                                  Estimate Attire_Accessories Beauty_spa  \
# 0    $42704 is the Estimated Wedding Cost              $2294       $630
# 1    $42485 is the Estimated Wedding Cost              $2005       $642
# 2    $19632 is the Estimated Wedding Cost              $3230       $234
# 3    $11363 is the Estimated Wedding Cost              $2082        $58
# 4    $35786 is the Estimated Wedding Cost              $3407       $428
# ..                                    ...                ...        ...
# 975  $21355 is the Estimated Wedding Cost              $4002       $292
# 976  $21359 is the Estimated Wedding Cost              $1782       $246
# 977  $28469 is the Estimated Wedding Cost              $2638       $406
# 978  $32907 is the Estimated Wedding Cost              $2287       $503
# 979  $26540 is the Estimated Wedding Cost              $2098       $455
#
#     Entertainment Flowers_Decorations  Gifts invitations Photography Planner  \
# 0            $346               $1652  $8530      $13227        $877   $1275
# 1            $214                $240  $1338       $9020       $2308   $2719
# 2            $312                $320  $1085       $2650        $809   $2021
# 3            $253               $1204   $604         $95       $3534    $445
# 4            $196                $325  $4902      $10597       $3224    $544
# ..            ...                 ...    ...         ...         ...     ...
# 975          $169                $278  $3164       $6848       $2056    $372
# 976          $222                $317   $856       $3863        $881   $1439
# 977          $240                $898  $5639       $6962       $2179    $346
# 978          $182               $1329  $8392      $10828       $2849    $704
# 979          $174                $301  $1047       $7169       $1596   $2527
#
#     venue_Catering_rental
# 0                   $1320
# 1                   $1012
# 2                    $194
# 3                   $2950
# 4                    $306
# ..                    ...
# 975                  $232
# 976                  $589
# 977                  $366
# 978                  $565
# 979                  $792
#
# [980 rows x 20 columns]

# %%
"""To check for Nan"""
df.isna().sum()
# Out:
# Unnamed: 0                 0
# Summary                    0
# Season                     0
# Wedding_destination        0
# Guest                      0
# Location                   0
# Describing_words         117
# Priority_1               760
# Priority_2               764
# Priority_3               772
# Estimate                   0
# Attire_Accessories         1
# Beauty_spa                 1
# Entertainment              1
# Flowers_Decorations        2
# Gifts                      3
# invitations                3
# Photography                8
# Planner                   17
# venue_Catering_rental     39
# dtype: int64

# %%
"""To replace Nan as None in string columns and replace Nan as $0 in number columns"""
df.iloc[:,0:10]=df.iloc[:,0:10].fillna("None")
df.iloc[:,10:20]=df.iloc[:,10:20].fillna('$0')
df
# Out:
#      Unnamed: 0                                            Summary  \
# 0             0  How much does a summer wedding in Camarillo CA...
# 1             1  How much does a spring wedding in Mobile AL wi...
# 2             2  How much does a spring wedding with 50 to 100 ...
# 3             3  How much does a fall wedding in Dayton OH with...
# 4             4  How much does a spring wedding in Gloucester M...
# ..          ...                                                ...
# 975         975  How much does a summer wedding in Phoenix az w...
# 976         976  How much does a summer wedding in Decatur IL w...
# 977         977  How much does a fall wedding in Mount Pleasant...
# 978         978  How much does a spring wedding in Bethlehem PA...
# 979         979  How much does a summer wedding in Sheffield MA...
#
#              Season Wedding_destination  \
# 0    Summer Wedding        Camarillo CA
# 1    Spring Wedding           Mobile AL
# 2    Spring Wedding      None specified
# 3      Fall Wedding           Dayton OH
# 4    Spring Wedding       Gloucester MA
# ..              ...                 ...
# 975  Summer Wedding          Phoenix az
# 976  Summer Wedding          Decatur IL
# 977    Fall Wedding   Mount Pleasant SC
# 978  Spring Wedding        Bethlehem PA
# 979  Summer Wedding        Sheffield MA
#
#                                                  Guest  \
# 0    This estimate is based on having 175 guests wi...
# 1    This estimate is based on having 175 guests wi...
# 2    This estimate is based on having 75 guests wit...
# 3    This estimate is based on having 38 guests wit...
# 4    This estimate is based on having 125 guests wi...
# ..                                                 ...
# 975  This estimate is based on having 75 guests wit...
# 976  This estimate is based on having 75 guests wit...
# 977  This estimate is based on having 125 guests wi...
# 978  This estimate is based on having 125 guests wi...
# 979  This estimate is based on having 125 guests wi...
#
#                                Location            Describing_words  \
# 0                      a garden or park                       Pinks
# 1                                 Other                        None
# 2                      a garden or park                       Blues
# 3    a church or other place of worship   Romantic Vintage Intimate
# 4                     an event facility                     Purples
# ..                                  ...                         ...
# 975  a church or other place of worship  Elegant Garden Traditional
# 976                             Purples                        None
# 977                      a farm or barn                     Purples
# 978  a church or other place of worship    Simple Traditional Other
# 979            a family or friends home                       Blues
#
#                                          Priority_1  \
# 0                                              None
# 1                                              None
# 2                                              None
# 3    Attire & Accessories (Wedding Dress Suit etc.)
# 4                                              None
# ..                                              ...
# 975  Attire & Accessories (Wedding Dress Suit etc.)
# 976                                            None
# 977                                            None
# 978         Event Food Service Catering Bar Service
# 979                                            None
#
#                                   Priority_2            Priority_3  \
# 0                                       None                  None
# 1                                       None                  None
# 2                                       None                  None
# 3    Event Food Service Catering Bar Service   Photography & Video
# 4                                       None                  None
# ..                                       ...                   ...
# 975  Event Food Service Catering Bar Service  Event Location/Venue
# 976                                     None                  None
# 977                                     None                  None
# 978                     Event Location/Venue         Event Rentals
# 979                                     None                  None
#
#                                  Estimate Attire_Accessories Beauty_spa  \
# 0    $42704 is the Estimated Wedding Cost              $2294       $630
# 1    $42485 is the Estimated Wedding Cost              $2005       $642
# 2    $19632 is the Estimated Wedding Cost              $3230       $234
# 3    $11363 is the Estimated Wedding Cost              $2082        $58
# 4    $35786 is the Estimated Wedding Cost              $3407       $428
# ..                                    ...                ...        ...
# 975  $21355 is the Estimated Wedding Cost              $4002       $292
# 976  $21359 is the Estimated Wedding Cost              $1782       $246
# 977  $28469 is the Estimated Wedding Cost              $2638       $406
# 978  $32907 is the Estimated Wedding Cost              $2287       $503
# 979  $26540 is the Estimated Wedding Cost              $2098       $455
#
#     Entertainment Flowers_Decorations  Gifts invitations Photography Planner  \
# 0            $346               $1652  $8530      $13227        $877   $1275
# 1            $214                $240  $1338       $9020       $2308   $2719
# 2            $312                $320  $1085       $2650        $809   $2021
# 3            $253               $1204   $604         $95       $3534    $445
# 4            $196                $325  $4902      $10597       $3224    $544
# ..            ...                 ...    ...         ...         ...     ...
# 975          $169                $278  $3164       $6848       $2056    $372
# 976          $222                $317   $856       $3863        $881   $1439
# 977          $240                $898  $5639       $6962       $2179    $346
# 978          $182               $1329  $8392      $10828       $2849    $704
# 979          $174                $301  $1047       $7169       $1596   $2527
#
#     venue_Catering_rental
# 0                   $1320
# 1                   $1012
# 2                    $194
# 3                   $2950
# 4                    $306
# ..                    ...
# 975                  $232
# 976                  $589
# 977                  $366
# 978                  $565
# 979                  $792
#
# [980 rows x 20 columns]

# %%
"""Estimate column is the total amount of money for the wedding. Hence we just need to extract the amount and remove the strings. later we need to convert the column to int for calculations"""

df['Estimate']=df['Estimate'].map(lambda x:x.lstrip('$').rstrip(' is the Estimated Wedding Cost')).astype(int)
df['Estimate']
# Out:
# 0      42704
# 1      42485
# 2      19632
# 3      11363
# 4      35786
#        ...
# 975    21355
# 976    21359
# 977    28469
# 978    32907
# 979    26540
# Name: Estimate, Length: 980, dtype: int64

# %%
"""For numerical columns we need to remove the $ sign and convert it to int for calculations"""
for column in df.columns[11:20]:
  df[column]=df[column].map(lambda x:x.lstrip('$'))
  df[column]=df[column].astype(int)
df
# Out:
#      Unnamed: 0                                            Summary  \
# 0             0  How much does a summer wedding in Camarillo CA...
# 1             1  How much does a spring wedding in Mobile AL wi...
# 2             2  How much does a spring wedding with 50 to 100 ...
# 3             3  How much does a fall wedding in Dayton OH with...
# 4             4  How much does a spring wedding in Gloucester M...
# ..          ...                                                ...
# 975         975  How much does a summer wedding in Phoenix az w...
# 976         976  How much does a summer wedding in Decatur IL w...
# 977         977  How much does a fall wedding in Mount Pleasant...
# 978         978  How much does a spring wedding in Bethlehem PA...
# 979         979  How much does a summer wedding in Sheffield MA...
#
#              Season Wedding_destination  \
# 0    Summer Wedding        Camarillo CA
# 1    Spring Wedding           Mobile AL
# 2    Spring Wedding      None specified
# 3      Fall Wedding           Dayton OH
# 4    Spring Wedding       Gloucester MA
# ..              ...                 ...
# 975  Summer Wedding          Phoenix az
# 976  Summer Wedding          Decatur IL
# 977    Fall Wedding   Mount Pleasant SC
# 978  Spring Wedding        Bethlehem PA
# 979  Summer Wedding        Sheffield MA
#
#                                                  Guest  \
# 0    This estimate is based on having 175 guests wi...
# 1    This estimate is based on having 175 guests wi...
# 2    This estimate is based on having 75 guests wit...
# 3    This estimate is based on having 38 guests wit...
# 4    This estimate is based on having 125 guests wi...
# ..                                                 ...
# 975  This estimate is based on having 75 guests wit...
# 976  This estimate is based on having 75 guests wit...
# 977  This estimate is based on having 125 guests wi...
# 978  This estimate is based on having 125 guests wi...
# 979  This estimate is based on having 125 guests wi...
#
#                                Location            Describing_words  \
# 0                      a garden or park                       Pinks
# 1                                 Other                        None
# 2                      a garden or park                       Blues
# 3    a church or other place of worship   Romantic Vintage Intimate
# 4                     an event facility                     Purples
# ..                                  ...                         ...
# 975  a church or other place of worship  Elegant Garden Traditional
# 976                             Purples                        None
# 977                      a farm or barn                     Purples
# 978  a church or other place of worship    Simple Traditional Other
# 979            a family or friends home                       Blues
#
#                                          Priority_1  \
# 0                                              None
# 1                                              None
# 2                                              None
# 3    Attire & Accessories (Wedding Dress Suit etc.)
# 4                                              None
# ..                                              ...
# 975  Attire & Accessories (Wedding Dress Suit etc.)
# 976                                            None
# 977                                            None
# 978         Event Food Service Catering Bar Service
# 979                                            None
#
#                                   Priority_2            Priority_3  Estimate  \
# 0                                       None                  None     42704
# 1                                       None                  None     42485
# 2                                       None                  None     19632
# 3    Event Food Service Catering Bar Service   Photography & Video     11363
# 4                                       None                  None     35786
# ..                                       ...                   ...       ...
# 975  Event Food Service Catering Bar Service  Event Location/Venue     21355
# 976                                     None                  None     21359
# 977                                     None                  None     28469
# 978                     Event Location/Venue         Event Rentals     32907
# 979                                     None                  None     26540
#
#      Attire_Accessories  Beauty_spa  Entertainment  Flowers_Decorations  \
# 0                  2294         630            346                 1652
# 1                  2005         642            214                  240
# 2                  3230         234            312                  320
# 3                  2082          58            253                 1204
# 4                  3407         428            196                  325
# ..                  ...         ...            ...                  ...
# 975                4002         292            169                  278
# 976                1782         246            222                  317
# 977                2638         406            240                  898
# 978                2287         503            182                 1329
# 979                2098         455            174                  301
#
#      Gifts  invitations  Photography  Planner  venue_Catering_rental
# 0     8530        13227          877     1275                   1320
# 1     1338         9020         2308     2719                   1012
# 2     1085         2650          809     2021                    194
# 3      604           95         3534      445                   2950
# 4     4902        10597         3224      544                    306
# ..     ...          ...          ...      ...                    ...
# 975   3164         6848         2056      372                    232
# 976    856         3863          881     1439                    589
# 977   5639         6962         2179      346                    366
# 978   8392        10828         2849      704                    565
# 979   1047         7169         1596     2527                    792
#
# [980 rows x 20 columns]

# %%
""" Save to csv"""
df.to_csv('processed_data.csv')
