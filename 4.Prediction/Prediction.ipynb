# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
#Loading dataset
dataset = pd.read_csv('processed_data.csv')
wedding_dataset = dataset[["Season", "Wedding_destination","Location","Priority_1","Guest_number","Total_Estimate"]]
wedding_dataset
# Out:
#              Season Wedding_destination                            Location  \
# 0    Summer Wedding        Camarillo CA                    a garden or park
# 1    Spring Wedding           Mobile AL                               Other
# 2    Spring Wedding      None specified                    a garden or park
# 3      Fall Wedding           Dayton OH  a church or other place of worship
# 4    Spring Wedding       Gloucester MA                   an event facility
# ..              ...                 ...                                 ...
# 975  Summer Wedding          Phoenix az  a church or other place of worship
# 976  Summer Wedding          Decatur IL                             Purples
# 977    Fall Wedding   Mount Pleasant SC                      a farm or barn
# 978  Spring Wedding        Bethlehem PA  a church or other place of worship
# 979  Summer Wedding        Sheffield MA            a family or friends home
#
# ...

# %%
from re import I
from sklearn.preprocessing import LabelEncoder
le_0= LabelEncoder()
le_1= LabelEncoder()
le_2= LabelEncoder()
le_3= LabelEncoder()

wedding_dataset["Season"]=le_0.fit_transform(wedding_dataset["Season"])
wedding_dataset["Wedding_destination"]=le_1.fit_transform(wedding_dataset["Wedding_destination"])
wedding_dataset["Location"]=le_2.fit_transform(wedding_dataset["Location"])
wedding_dataset["Priority_1"]=le_3.fit_transform(wedding_dataset["Priority_1"])
wedding_dataset
#   wedding_dataset[["Season", "Wedding_destination","Location","Priority_1"]] = wedding_dataset[["Season", "Wedding_destination","Location","Priority_1"]].apply(le.fit_transform)
# wedding_dataset
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
X = wedding_dataset.iloc[:, :-1].values
y = wedding_dataset.iloc[:, -1].values

# %%
#Train, Test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
# X_train =X_train.reshape(-1, 1)
# y_train =y_train.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
#display adjusted R-squared
adjusted_R2=1 - (1-regressor.score(X, y))*(len(y)-1)/(len(y)-X.shape[1]-1)
adjusted_R2
# Out:
# 0.7984162488997255

# %%
ynew = regressor.predict([[2,210,16,4,125]])
ynew
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([54158.16070549])

# %%
ynew = regressor.predict([[le_0.transform(['Spring Wedding']),le_1.transform(['Gloucester MA']),le_2.transform(['a farm or barn']),le_3.transform(['Bakery (Wedding Cake/dessert)']),125]])
ynew
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:746: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   array = np.asarray(array, order=order, dtype=dtype)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# array([57291.85755444])
